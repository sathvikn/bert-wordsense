# %% [markdown]
# Exploring frequencies for different stimuli in the MASC corpus

# %%
import pandas as pd

# %%
corpus = pd.read_csv('../data/google_ws_data_wn_synsets.csv', encoding='latin-1')
corpus = corpus.drop_duplicates()
corpus
# Out:
#         Unnamed: 0      lemma       word   pos  \
# 0                0      court      court  NOUN
# 1                1      court      court  NOUN
# 2                2  honorable  HONORABLE   ADJ
# 3                3       date       Date  NOUN
# 4                4       date       Date  NOUN
# ...            ...        ...        ...   ...
# 326902          41     period     period  NOUN
# 326903          42     period     period  NOUN
# 326904          43       time       time  NOUN
# 326905          44     period     period  NOUN
# 326906          45     period     period  NOUN
#
#                                                noad_sense  \
# 0       /dictionary/sense/en_us_NOAD3e_2012/m_en_us123...
# 1       /dictionary/sense/en_us_NOAD3e_2012/m_en_us123...
# 2       /dictionary/sense/en_us_NOAD3e_2012/m_en_us125...
# 3       /dictionary/sense/en_us_NOAD3e_2012/m_en_us123...
# 4       /dictionary/sense/en_us_NOAD3e_2012/m_en_us123...
# ...                                                   ...
# 326902  /dictionary/sense/en_us_NOAD3e_2012/m_en_us127...
# 326903  /dictionary/sense/en_us_NOAD3e_2012/m_en_us127...
# 326904  /dictionary/sense/en_us_NOAD3e_2012/m_en_us129...
# 326905  /dictionary/sense/en_us_NOAD3e_2012/m_en_us127...
# 326906  /dictionary/sense/en_us_NOAD3e_2012/m_en_us127...
#
#                           wn_sense  \
# 0             Synset('court.n.02')
# 1             Synset('court.n.05')
# 2         Synset('estimable.s.02')
# 3              Synset('date.n.08')
# 4              Synset('date.n.08')
# ...                            ...
# 326902       Synset('period.n.07')
# 326903       Synset('period.n.03')
# 326904  Synset('prison_term.n.01')
# 326905       Synset('period.n.07')
# 326906       Synset('period.n.03')
#
#                                                    source  \
# 0       ../data/word_sense_disambigation_corpora/masc/...
# 1       ../data/word_sense_disambigation_corpora/masc/...
# 2       ../data/word_sense_disambigation_corpora/masc/...
# 3       ../data/word_sense_disambigation_corpora/masc/...
# 4       ../data/word_sense_disambigation_corpora/masc/...
# ...                                                   ...
# 326902  ../data/word_sense_disambigation_corpora/masc/...
# 326903  ../data/word_sense_disambigation_corpora/masc/...
# 326904  ../data/word_sense_disambigation_corpora/masc/...
# 326905  ../data/word_sense_disambigation_corpora/masc/...
# 326906  ../data/word_sense_disambigation_corpora/masc/...
#
#                                                  sentence
# 0       / spoken / court transcript / Day3PMSession.tx...
# 1       / spoken / court transcript / Day3PMSession.tx...
# 2                   HONORABLE JOHN E. JONES , III Date :
# 3                   HONORABLE JOHN E. JONES , III Date :
# 4                   HONORABLE JOHN E. JONES , III Date :
# ...                                                   ...
# 326902  / written / newspaper : newswire / wsj_0127.tx...
# 326903  / written / newspaper : newswire / wsj_0127.tx...
# 326904  / written / newspaper : newswire / wsj_0127.tx...
# 326905  / written / newspaper : newswire / wsj_0127.tx...
# 326906  / written / newspaper : newswire / wsj_0127.tx...
#
# [326907 rows x 8 columns]

# %% [markdown]
# Now we see how many words we can use to compare to the experimental data, as a way to augment SEMCOR

# %%
#Cleaning our data from the FB JSON
import json
stimuli = json.load(open('../data/expt_stimuli.json', 'r'))
inputs = stimuli['inputs']
input_senses = [list(inputs[k].keys()) for k in inputs.keys()]
def wn_synset(fb_sense):
    parts = fb_sense.split('_')
    synset_str = '_'.join(parts[:len(parts) - 2]) + '.' + '.'.join(parts[-2:])
    return synset_str
expt_senses = [wn_synset(item) for sublist in input_senses for item in sublist if item not in ['type', 'senses']]

# %%
strip_synset = lambda s: s.strip("Synset(')")
corpus['wn_sense'] = corpus['wn_sense'].apply(strip_synset)
expt_words = corpus[corpus['wn_sense'].isin(expt_senses)][['lemma', 'word','pos', 'wn_sense', 'sentence']]
expt_words
# Out:
#            lemma       word   pos       wn_sense  \
# 108         case       case  NOUN      case.n.01
# 173         case       case  NOUN      case.n.01
# 270         case       case  NOUN      case.n.01
# 311     indicate  indicated  VERB  indicate.v.02
# 312     indicate  indicated  VERB  indicate.v.03
# ...          ...        ...   ...            ...
# 326629      book       book  NOUN      book.n.01
# 326630      book       book  NOUN      book.n.02
# 326631      book       book  NOUN    record.n.05
# 326649       ask     asking  VERB       ask.v.01
# 326834     heart      heart  NOUN     heart.n.01
#
#                                                  sentence
# 108     Subsequently , the reporters were , if memory ...
# 173     We 're brought here today by that , as well as...
# 270     I certainly understand the opinion and orders ...
# 311     And what I mean by that , with regard to all o...
# 312     And what I mean by that , with regard to all o...
# ...                                                   ...
# 326629  More shocking was the city of Hiroshima , whic...
# 326630  More shocking was the city of Hiroshima , whic...
# 326631  More shocking was the city of Hiroshima , whic...
# 326649  Someone woke him to say Gen. Hap Arnold , chie...
# 326834  In his heart , he holds the unshakable convict...
#
# [7872 rows x 5 columns]

# %%
shared_words = ['degree', 'table', 'foot', 'plane', 'right', 'model']

expt_words[(expt_words['lemma'].isin(shared_words)) & (expt_words['pos'] == 'NOUN')].groupby('wn_sense').agg('count')
# Out:
#                       lemma  pos  sentence
# wn_sense
# academic_degree.n.01      6    6         6
# airplane.n.01            12   12        12
# degree.n.01              26   26        26
# foot.n.01                49   49        49
# model.n.01               38   38        38
# model.n.03               10   10        10

# %%
expt_words[(expt_words['lemma'].isin(shared_words)) & (expt_words['pos'] == 'NOUN')]['wn_sense'].unique()
# Out:
# array(['degree.n.01', 'airplane.n.01', 'model.n.01', 'foot.n.01',
#        'academic_degree.n.01', 'model.n.03'], dtype=object)
