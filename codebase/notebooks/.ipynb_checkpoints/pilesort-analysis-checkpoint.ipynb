# %%
import json
import warnings
warnings.simplefilter('ignore')
from core.analysis import *

# %% [markdown]
# ## Data Prep

# %%
db = access_db()

# %%
trials = get_trial_data(db)

# %%
participants = get_participant_data(db)

# %%
wids = [27046826551,67313721753,14715705020,65643517184,86979612220,4949336941,26312944991,46875911951,43605166255]
#Worker IDs of subjects who completed expt
wids = [str(i) for i in wids]

# %% [markdown]
# Getting data for users who completed the experiment

# %%
user_df = participants[participants['workerID'].isin(wids) & participants['completedTask'] == 1]
user_df
# Out:
#                   userID     workerID      userIP  completedTask  timeTaken
# 22  -M3pVTw9ili6muvdZKg4  27046826551  -188934845              1    546.814
# 23  -M3qqejnlf4v_ja8eE7n  67313721753   727219182              1    526.296
# 29  -M3rSxyqKh87n8IxCNFz  14715705020  1146968680              1    597.604
# 31  -M3tou9y2NuJSM2wEped  65643517184   -15487531              1    712.426
# 33  -M3wWKZuvM6607THGsj3  86979612220 -1107186255              1    308.230
# 34  -M3xbEdg3XIZca4MA7SZ  26312944991 -1470029051              1    924.305
# 36  -M40VLLla6hlhfPLwyWk   4949336941 -1012892879              1    921.908
# 55  -M4RJU1sPJwCqxkN93qZ  46875911951  1225707233              1    706.181
# 58  -M4WPYQVe_g2Cz7JGkvf  43605166255   565906706              1    380.887

# %%
users = participants[participants['workerID'].isin(wids) & participants['completedTask'] == 1]['userID']
results = trials[trials['userID'].isin(users)]
results
# Out:
#                   trialID                userID  trialIndex trialType  \
# 206  -M3pVhmrS4LVzC6_gIcJ  -M3pVTw9ili6muvdZKg4           1  training
# 207  -M3pVhmrS4LVzC6_gIcJ  -M3pVTw9ili6muvdZKg4           1  training
# 208  -M3pVhmrS4LVzC6_gIcJ  -M3pVTw9ili6muvdZKg4           1  training
# 209  -M3pVmug0DJj2iajKInK  -M3pVTw9ili6muvdZKg4           2  training
# 210  -M3pVmug0DJj2iajKInK  -M3pVTw9ili6muvdZKg4           2  training
# ..                    ...                   ...         ...       ...
# 775  -M4WQil33JL5IUOVqtkX  -M4WPYQVe_g2Cz7JGkvf          17    repeat
# 776  -M4WQil33JL5IUOVqtkX  -M4WPYQVe_g2Cz7JGkvf          17    repeat
# 777  -M4WQktKprTLtiCVjEuZ  -M4WPYQVe_g2Cz7JGkvf          18    repeat
# 778  -M4WQktKprTLtiCVjEuZ  -M4WPYQVe_g2Cz7JGkvf          18    repeat
# 779  -M4WQktKprTLtiCVjEuZ  -M4WPYQVe_g2Cz7JGkvf          18    repeat
#
#      prevChanged    lemma                                  sense      x      y
# 206            1   bank_n                              bank_n_01  173.0  360.0
# 207            1   bank_n                              bank_n_05  614.0  362.0
# 208            1   bank_n  depository_financial_institution_n_01  499.0  368.0
# 209            0   bass_n                              bass_n_03  241.0  402.0
# 210            0   bass_n                              bass_n_04  723.0  324.0
# ..           ...      ...                                    ...    ...    ...
# 775            1   book_n                              book_n_02  438.0  388.0
# 776            1   book_n                            record_n_05  434.0  361.0
# 777            0  glass_n                             glass_n_01  433.0  333.0
# 778            0  glass_n                             glass_n_02  410.0  348.0
# 779            0  glass_n                             glass_n_03  439.0  354.0
#
# [562 rows x 9 columns]

# %% [markdown]
# ## Repeat Trial Results

# %% [markdown]
# Original WN sense definitions(make sure to click "Show Sense Numbers" under "Display Options"): http://wordnetweb.princeton.edu/perl/webwn

# %% [markdown]
# Distance matrices for when a subject got the same word (2x per trial). Spearman rank correlations between the subject's original and repeat trials are also recorded.

# %%
repeat_corr = plot_all_repeats(results, users)
# Out:
# User 22  Correlation  0.45940746440938823
# User 23  Correlation  0.7341597796143251
# User 29  Correlation  0.6554621848739496
# User 31  Correlation  0.8508410434878082
# User 33  Correlation  -0.2100840336134454
# User 34  Correlation  0.34210526315789475
# User 36  Correlation  0.6470588235294118
# User 55  Correlation  0.2162534435261708
# User 58  Correlation  0.3676470588235294
# Correlation of all original vs. repeat trials 0.4429744199162231

# %% [markdown]
# ## Shared Words

# %% [markdown]
# All subjects received a set of homonymous words. It appears there's some consistency in the results for foot, table, degree, and plane, but model and right were harder to distinguish.

# %%
plot_all_shared(results, users)

# %% [markdown]
# Spearman rank correlations between one subject's data and the average of the rest of the subjects

# %%
shared_results = results[results['trialType'] == 'shared']
shared_corrs = group_consistency(shared_results, users)
# Out:
# Hold One Out Correlation for User 22 -0.027329898660652777
# Hold One Out Correlation for User 23 0.767339462395251
# Hold One Out Correlation for User 29 0.6685313672375064
# Hold One Out Correlation for User 31 0.5444956733160823
# Hold One Out Correlation for User 33 0.06622244675465866
# Hold One Out Correlation for User 34 0.3973346805279519
# Hold One Out Correlation for User 36 -0.245969087945875
# Hold One Out Correlation for User 55 0.8167435099741234
# Hold One Out Correlation for User 58 -0.23335528856403523

# %% [markdown]
# ## MDS for Shared Trials

# %%
all_shared_defs = display_sense_definitions(results, 'shared')

# %%
plot_individual_mds(results, 'foot_n', 'shared', users, db, all_shared_defs)
# Out:
#          Sense    Type  \
# 212  foot_n_01  foot_n
# 213  foot_n_02  foot_n
# 214  foot_n_03  foot_n
#
#                                                           Definition
# 212       the part of the leg of a human being below the ankle joint
# 213  a linear unit of length equal to 12 inches or a third of a yard
# 214                                       the lower part of anything

# %%
plot_individual_mds(results, 'table_n', 'shared', users, db, all_shared_defs)
# Out:
#           Sense     Type  \
# 215  table_n_01  table_n
# 216  table_n_02  table_n
# 217  table_n_03  table_n
#
#                                                                                                Definition
# 215                                                            a set of data arranged in rows and columns
# 216  a piece of furniture having a smooth flat top that is usually supported by one or more vertical legs
# 217                                         a piece of furniture with tableware for a meal laid out on it

# %%
plot_individual_mds(results, 'plane_n', 'shared', users, db, all_shared_defs)
# Out:
#              Sense     Type  \
# 218  airplane_n_01  plane_n
# 219     plane_n_02  plane_n
# 220     plane_n_03  plane_n
#
#                                                                  Definition
# 218  an aircraft that has a fixed wing and is powered by propellers or jets
# 219                        (mathematics) an unbounded two-dimensional shape
# 220                                     a level of existence or development

# %%
plot_individual_mds(results, 'degree_n', 'shared', users, db, all_shared_defs)
# Out:
#                     Sense      Type  \
# 221  academic_degree_n_01  degree_n
# 222           degree_n_01  degree_n
# 223           degree_n_02  degree_n
#
#                                                                                                                      Definition
# 221  an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
# 222                                                                     a position on a scale of intensity or amount or quality
# 223                                        a specific identifiable position in a continuum or series or especially in a process

# %%
plot_individual_mds(results, 'right_n', 'shared', users, db, all_shared_defs)
# Out:
#           Sense     Type  \
# 224  right_n_01  right_n
# 225  right_n_02  right_n
# 226  right_n_04  right_n
#
#                                                                                                                       Definition
# 224  an abstract idea of that which is due to a person or governmental body by law or tradition or nature; ; - Eleanor Roosevelt
# 225              location near or direction toward the right side; i.e. the side to the south when a person or object faces east
# 226      those who support political or social or economic conservatism; those who believe that things are better left unchanged

# %%
plot_individual_mds(results, 'model_n', 'shared', users, db, all_shared_defs)
# Out:
#           Sense     Type  \
# 227  model_n_01  model_n
# 228  model_n_02  model_n
# 229  model_n_03  model_n
#
#                                                        Definition
# 227     a hypothetical description of a complex entity or process
# 228                                             a type of product
# 229  a person who poses for a photographer or painter or sculptor

# %% [markdown]
# ## Consistency Metrics

# %%
user_time_word_changes = get_time_and_changes(results, user_df)
consistency = pd.DataFrame({'Group Consistency': shared_corrs, 'Self Consistency': repeat_corr})
corrs = user_time_word_changes.merge(consistency, on = user_time_word_changes.index).drop('key_0', axis = 1)
corrs['Correlation with SN'] = my_correlations(participants, trials, results)
corrs
# Out:
#                  userID  timeTaken  changes  Group Consistency  \
# 0  -M3pVTw9ili6muvdZKg4    546.814        5          -0.027330
# 1  -M3qqejnlf4v_ja8eE7n    526.296        3           0.767339
# 2  -M3rSxyqKh87n8IxCNFz    597.604       14           0.668531
# 3  -M3tou9y2NuJSM2wEped    712.426       10           0.544496
# 4  -M3wWKZuvM6607THGsj3    308.230        3           0.066222
# 5  -M3xbEdg3XIZca4MA7SZ    924.305        9           0.397335
# 6  -M40VLLla6hlhfPLwyWk    921.908        0          -0.245969
# 7  -M4RJU1sPJwCqxkN93qZ    706.181       11           0.816744
# 8  -M4WPYQVe_g2Cz7JGkvf    380.887        3          -0.233355
#
#    Self Consistency  Correlation with SN
# 0          0.459407             0.328158
# 1          0.734160             0.782120
# 2          0.655462             0.571734
# 3          0.850841             0.585118
# 4         -0.210084             0.230193
# 5          0.342105             0.731799
# 6          0.647059            -0.115632
# 7          0.216253             0.790685
# 8          0.367647            -0.276231

# %% [markdown]
# **timeTaken:** Duration of experiment for each user (in seconds)
#
# **Changes:** Number of times a subject changed the existing layout (benefit of grid layout over similarity judgements)
#
# **Group Consistency:** Hold one out correlation on shared trials (taken from above results). Spearman rank correlation with subject's matrix and the average of all the other subjects' matrices.
#
# **Self Consistency**: Spearman rank correlation over the two repeated words a participant received
#
# **Correlation with SN:** The leftmost column in the dataframe is the Spearman rank correlation with my results, which would be the closet thing we have to ground truth data. For all the shared words, my correlation with the average was 1 for plane.n, degree.n, foot.n, and table.n, and 0.5 for right.n and model.n.

# %% [markdown]
# We replicate the self and group consistency metrics with matrices initialized for 100 random subjects.

# %%
random_self = simulate_self_correlation(100, db)
plot_consistency_hist(random_self, corrs['Self Consistency'], 
                      "Self Consistency of Subjects vs. Random Matrices")

# %%
random_group = [random_vs_all(shared_results) for _ in range(100)]
plot_consistency_hist(random_group, corrs['Group Consistency'], 
                      "Group Consistency of Subjects vs. Random Matrices")
